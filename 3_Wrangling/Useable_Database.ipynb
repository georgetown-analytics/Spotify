# %%
import pandas as pd

# %%
df_artist = pd.read_csv('artist.csv',index_col='id')
df_lyrics = pd.read_csv('lyric.csv',index_col='artist_id')

# %%
df_artist.sample(50)
# Out:
#                                 title  song_count  \
# id
# 7740                         Scarface          11
# 7464                    Roger Walters           1
# 269                         Ama Shola          12
# 8120                Smokin Armadillos           3
# 7716                         Saturnus           7
# 1010                     Blood Duster          11
# 1609                          Chicory           1
# 8710                              The           5
# 1102                     Bonnie Raitt           4
# 3318                      Funny Girls           1
# 2438                   Dinerman Annie           2
# 9503                            Vivid           4
# 8256                     Spina Bifida           6
# 7306                   Reo Speedwagon          52
# 8723                     The B.c. 52s           2
# 1325                             Bush          76
# 5761                     Menzel Idina           7
# 2599                    Dream Theater          85
# ...

# %%
df_artist = df_artist.drop(df_artist[df_artist['title'] == "A"].index)
df_artist_csv = df_artist['title']

# %%
df_artist_csv.to_csv('artist_useable_database.csv',index=False,sep='|')
# Out:
# /Users/adamgoldstein/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
df_lyrics.head()
# Out:
#            id                 title  \
# artist_id
# 1           1             6 O'clock
# 1           2            Going Down
# 1           3         Hi-Fi Serious
# 1           4    Hold Back The Rain
# 1           5  Hungry Like The Wolf
#
#                                                      content
# artist_id
# 1          6 o'clock on a tube stop, waiting for a subway...
# 1          Suck it up, we're going down\n30 seconds 'till...
# 1          Right back at you, record three\nMakes you wis...
# 1          Hold back the rain\nYes we're miles away from ...
# 1          Darken the city night is awire steam in the su...

# %%
df_artist_lyrics = df_artist.merge(df_lyrics,left_on = 'id',right_on='artist_id')

# %%
df_update_artist_lyrics = df_artist_lyrics.rename(columns={'title_x':'artist_name','title_y':'track_name'})

# %%
update = df_update_artist_lyrics.drop(df_update_artist_lyrics[df_update_artist_lyrics['artist_name'] == "A"].index)

# %%
update
# Out:
#                 artist_name  song_count                 slug  \
# id
# 22       A Canorous Quintet          11   a-canorous-quintet
# 23       A Canorous Quintet          11   a-canorous-quintet
# 24       A Canorous Quintet          11   a-canorous-quintet
# 25       A Canorous Quintet          11   a-canorous-quintet
# 26       A Canorous Quintet          11   a-canorous-quintet
# 27       A Canorous Quintet          11   a-canorous-quintet
# 28       A Canorous Quintet          11   a-canorous-quintet
# 29       A Canorous Quintet          11   a-canorous-quintet
# 30       A Canorous Quintet          11   a-canorous-quintet
# 31       A Canorous Quintet          11   a-canorous-quintet
# 32       A Canorous Quintet          11   a-canorous-quintet
# 33      A Flock of Seagulls          30  a-flock-of-seagulls
# 34      A Flock of Seagulls          30  a-flock-of-seagulls
# 35      A Flock of Seagulls          30  a-flock-of-seagulls
# ...
